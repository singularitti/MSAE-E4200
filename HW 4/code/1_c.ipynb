# %%
import numpy as np

# %%
sq3=1/np.sqrt(3)
sq6=1/np.sqrt(6)
sq2=1/np.sqrt(2)

# %%
u = np.array(
[[sq3, sq3, sq3],
[2*sq6, -sq6, -sq6],
[0,-sq2,sq2]]
)

# %%
kappa = np.array(
[[2,-1,-1],
[-1,2,-1],
[-1,-1,2]]
)

# %%
u.dot(kappa).dot(np.transpose(u))
# Out:
# array([[ 0.,  0.,  0.],
#        [ 0.,  3.,  0.],
#        [ 0.,  0.,  3.]])

# %%
ee = np.diag([1, 1, 1])

# %%
c3 = np.array(
[[0,0,1],
[1,0,0],
[0,1,0]]
)

# %%
c32=c3.dot(c3)

# %%
s1 = np.array(
[[1,0,0],
[0,0,1],
[0,1,0]]
)

# %%
s2=c32.dot(s1)

# %%
s3=c3.dot(s1)

# %%
p2 = ee + c3 + c32 - s1 - s2 - s3

# %%
p1 = ee + c3 + c32 + s1 + s2 + s3

# %%
pe = (2*ee-c3 -c32)
